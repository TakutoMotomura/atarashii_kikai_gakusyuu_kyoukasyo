# %%
from keras.datasets import mnist

(x_train,y_train),(x_test,y_test) = mnist.load_data()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(1,figsize=(18,6))
plt.subplots_adjust(wspace=0.5)
plt.gray()

for id in range(6):
    plt.subplot(2,6,id + 1)
    img = x_train[id,:,:]
    plt.pcolor(255-img)
    plt.text(22,26,"%d"% y_train[id],color='cornflowerblue',fontsize=18)
    plt.xlim(0,27)
    plt.ylim(27,0)

plt.show()

# %%
from keras.utils import np_utils

x_train = x_train.reshape(60000, 784)  # (A)
x_train = x_train.astype('float32')   # (B)
x_train = x_train / 255               # (C)
num_classes = 10
y_train = np_utils.to_categorical(y_train, num_classes)  # (D)

x_test = x_test.reshape(10000, 784)
x_test = x_test.astype('float32')
x_test = x_test / 255
y_test = np_utils.to_categorical(y_test, num_classes)


np.random.seed(1)                                         # (A)
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.optimizers import Adam

model = Sequential()                                      # (B)
model.add(Dense(16, input_dim=784, activation='sigmoid')) # (C)
model.add(Dense(10, activation='softmax'))                # (D)
model.compile(loss='categorical_crossentropy', 
              optimizer=Adam(), metrics=['accuracy'])     # (E)

import time

startTime = time.time()
history = model.fit(x_train, y_train, epochs=10, batch_size=1000,
                    verbose=1, validation_data=(x_test, y_test))  # (A)
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
print("Computation time:{0:.3f} sec".format(time.time() - startTime))
# Out:
# Epoch 1/10
# 60/60 [==============================] - 1s 10ms/step - loss: 1.9641 - accuracy: 0.5322 - val_loss: 1.6867 - val_accuracy: 0.6816
# Epoch 2/10
# 60/60 [==============================] - 0s 4ms/step - loss: 1.5224 - accuracy: 0.7226 - val_loss: 1.3588 - val_accuracy: 0.7672
# Epoch 3/10
# 60/60 [==============================] - 0s 3ms/step - loss: 1.2474 - accuracy: 0.7883 - val_loss: 1.1218 - val_accuracy: 0.8163
# Epoch 4/10
# 60/60 [==============================] - 0s 3ms/step - loss: 1.0405 - accuracy: 0.8283 - val_loss: 0.9415 - val_accuracy: 0.8475
# Epoch 5/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.8845 - accuracy: 0.8489 - val_loss: 0.8081 - val_accuracy: 0.8666
# Epoch 6/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.7685 - accuracy: 0.8644 - val_loss: 0.7088 - val_accuracy: 0.8755
# Epoch 7/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6810 - accuracy: 0.8748 - val_loss: 0.6333 - val_accuracy: 0.8841
# Epoch 8/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6135 - accuracy: 0.8831 - val_loss: 0.5754 - val_accuracy: 0.8908
# Epoch 9/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.5603 - accuracy: 0.8901 - val_loss: 0.5295 - val_accuracy: 0.8950
# Epoch 10/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.5176 - accuracy: 0.8946 - val_loss: 0.4928 - val_accuracy: 0.8977
# Test loss: 0.4927651882171631
# Test accuracy: 0.8977000117301941
# Computation time:3.627 sec

# %%
plt.figure(1,figsize=(10,4))
plt.subplots_adjust(wspace=0.5)

plt.subplot(1,2,1)
plt.plot(history.history['loss'],label='training',color='black')
plt.plot(history.history['val_loss'],label='test',color='cornflowerblue')
plt.ylim(0,10)
plt.legend()
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'],label='training',color='black')
plt.plot(history.history['val_accuracy'],label='test',color='cornflowerblue')
plt.ylim(0,1)
plt.legend()
plt.grid()
plt.xlabel('epoch')
plt.ylabel('acc')
plt.show()

# %%
def show_prediction():
    n_show = 96
    y = model.predict(x_test)
    plt.figure(2,figsize=(12,8))
    plt.gray()
    
    for i in range(n_show):
        plt.subplot(8,12,i+1)
        x = x_test[i,:]
        x = x.reshape(28,28)
        plt.pcolor(1-x)
        wk = y[i,:]
        prediction = np.argmax(wk)
        plt.text(22,25.5,"%d"% prediction,fontsize=12)
        
        if prediction != np.argmax(y_test[i,:]):
            plt.plot([0,27],[1,1],color='cornflowerblue',linewidth=5)
        
        plt.xlim(0,27)
        plt.ylim(27,0)
        plt.xticks([],"")
        plt.yticks([],"")

# main
show_prediction()
plt.show()

# %%
np.random.seed(1)
from keras.models import Sequential
from keras.layers import Dense,Activation
from keras.optimizers import Adam

model = Sequential()
model.add(Dense(16,input_dim=784,activation='relu'))
model.add(Dense(10,activation='softmax'))
model.compile(loss='categorical_crossentropy',optimizer=Adam(),metrics=['accuracy'])

startTime = time.time()
history = model.fit(x_train,y_train,batch_size=1000,epochs=10,verbose=1,validation_data=(x_test,y_test))
score = model.evaluate(x_test,y_test,verbose=0)
print('Test loss:',score[0])
print('Test accuracy:',score[1])
print('Computation time:{0:.3f}sec'.format(time.time() - startTime))
# Out:
# Epoch 1/10
# 60/60 [==============================] - 0s 7ms/step - loss: 1.6430 - accuracy: 0.5050 - val_loss: 0.9433 - val_accuracy: 0.7989
# Epoch 2/10
# 60/60 [==============================] - 0s 5ms/step - loss: 0.7009 - accuracy: 0.8377 - val_loss: 0.5216 - val_accuracy: 0.8720
# Epoch 3/10
# 60/60 [==============================] - 0s 4ms/step - loss: 0.4666 - accuracy: 0.8783 - val_loss: 0.4012 - val_accuracy: 0.8949
# Epoch 4/10
# 60/60 [==============================] - 0s 4ms/step - loss: 0.3817 - accuracy: 0.8967 - val_loss: 0.3471 - val_accuracy: 0.9053
# Epoch 5/10
# 60/60 [==============================] - 0s 5ms/step - loss: 0.3375 - accuracy: 0.9076 - val_loss: 0.3151 - val_accuracy: 0.9125
# Epoch 6/10
# 60/60 [==============================] - 0s 4ms/step - loss: 0.3094 - accuracy: 0.9140 - val_loss: 0.2942 - val_accuracy: 0.9178
# Epoch 7/10
# 60/60 [==============================] - 0s 5ms/step - loss: 0.2898 - accuracy: 0.9192 - val_loss: 0.2812 - val_accuracy: 0.9217
# Epoch 8/10
# 60/60 [==============================] - 0s 5ms/step - loss: 0.2748 - accuracy: 0.9233 - val_loss: 0.2680 - val_accuracy: 0.9236
# Epoch 9/10
# 60/60 [==============================] - 0s 4ms/step - loss: 0.2630 - accuracy: 0.9262 - val_loss: 0.2585 - val_accuracy: 0.9275
# Epoch 10/10
# 60/60 [==============================] - 0s 5ms/step - loss: 0.2525 - accuracy: 0.9295 - val_loss: 0.2511 - val_accuracy: 0.9288
# Test loss: 0.25105467438697815
# Test accuracy: 0.9287999868392944
# Computation time:3.790sec

# %%
show_prediction()
plt.show()

# %%
# 1層目の重みの可視化
w = model.layers[0].get_weights()[0]
plt.figure(1,figsize=(12,3))
plt.gray()
plt.subplots_adjust(wspace=0.35,hspace=0.5)

for i in range(16):
    plt.subplot(2,8,i+1)
    w1 = w[:,i]
    w1 = w1.reshape(28,28)
    plt.pcolor(-w1)
    plt.xlim(0,27)
    plt.ylim(27,0)
    plt.xticks([],"")
    plt.yticks([],"")
    plt.title("%d" % i)

plt.show()

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import numpy as np
from keras.datasets import mnist
from keras.utils import np_utils

(x_train,y_train),(x_test,y_test) = mnist.load_data()
x_train = x_train.reshape(60000,28,28,1)
x_test = x_test.reshape(10000,28,28,1)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
num_classes = 10
y_train = np_utils.to_categorical(y_train,num_classes)
y_test = np_utils.to_categorical(y_test,num_classes)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

id_img = 2
myfil1 = np.array([[1,1,1],[1,1,1],[-2,-2,-2]],dtype=float)
myfil2 = np.array([[-2,1,1],[-2,1,1],[-2,1,1]],dtype=float)

x_img = x_train[id_img,:,:,0]
img_h = 28
img_w = 28
x_img = x_img.reshape(img_h,img_w)
out_img1 = np.zeros_like(x_img)
out_img2 = np.zeros_like(x_img)

# filter
for ih in range(img_h - 3 + 1):
    for iw in range(img_w - 3 + 1 ):
        img_part = x_img[ih:ih + 3,iw:iw + 3]
        out_img1[ih+1,iw+1] = np.dot(img_part.reshape(-1),myfil1.reshape(-1))
        out_img2[ih+1,iw+1] = np.dot(img_part.reshape(-1),myfil2.reshape(-1))

# show
plt.figure(1,figsize=(12,3.2))
plt.subplots_adjust(wspace=0.5)
plt.gray()
plt.subplot(1,3,1)
plt.pcolor(1 - x_img)
plt.xlim(-1,29)
plt.ylim(29,-1)
plt.subplot(1,3,2)
plt.pcolor(-out_img1)
plt.xlim(-1,29)
plt.ylim(29,-1)
plt.subplot(1,3,3)
plt.pcolor(-out_img2)
plt.xlim(-1,29)
plt.ylim(29,-1)
plt.show()

# %%
np.random.seed(1)
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D
from keras.layers import Activation,Dropout,Flatten,Dense
from keras.optimizers import Adam
import time

model = Sequential()
model.add(Conv2D(8, (3, 3), padding='same',
           input_shape=(28, 28, 1), activation='relu'))
model.add(Flatten())
model.add(Dense(10,activation='softmax'))
model.compile(loss='categorical_crossentropy',optimizer=Adam(),metrics=['accuracy'])
startTime = time.time()
history = model.fit(x_train,y_train,batch_size=1000,epochs=20,verbose=1,validation_data=(x_test,y_test))
score = model.evaluate(x_test,y_test,verbose=0)
print('Test loss:',score[0])
print('Test accuracy:',score[1])
print('Computation time:{0:.3f} sec'.format(time.time() - startTime))
# Out:
# Epoch 1/20
# 60/60 [==============================] - 4s 66ms/step - loss: 0.7127 - accuracy: 0.8213 - val_loss: 0.3297 - val_accuracy: 0.9081
# Epoch 2/20
# 60/60 [==============================] - 4s 62ms/step - loss: 0.3154 - accuracy: 0.9097 - val_loss: 0.2813 - val_accuracy: 0.9199
# Epoch 3/20
# 60/60 [==============================] - 4s 68ms/step - loss: 0.2755 - accuracy: 0.9222 - val_loss: 0.2508 - val_accuracy: 0.9299
# Epoch 4/20
# 60/60 [==============================] - 5s 85ms/step - loss: 0.2458 - accuracy: 0.9306 - val_loss: 0.2273 - val_accuracy: 0.9369
# Epoch 5/20
# 60/60 [==============================] - 5s 90ms/step - loss: 0.2200 - accuracy: 0.9382 - val_loss: 0.2034 - val_accuracy: 0.9422
# Epoch 6/20
# 60/60 [==============================] - 5s 86ms/step - loss: 0.1967 - accuracy: 0.9457 - val_loss: 0.1835 - val_accuracy: 0.9482
# Epoch 7/20
# 60/60 [==============================] - 5s 85ms/step - loss: 0.1764 - accuracy: 0.9514 - val_loss: 0.1675 - val_accuracy: 0.9538
# Epoch 8/20
# 60/60 [==============================] - 5s 85ms/step - loss: 0.1596 - accuracy: 0.9565 - val_loss: 0.1544 - val_accuracy: 0.9567
# Epoch 9/20
# 60/60 [==============================] - 5s 85ms/step - loss: 0.1457 - accuracy: 0.9604 - val_loss: 0.1397 - val_accuracy: 0.9614
# Epoch 10/20
# 60/60 [==============================] - 5s 85ms/step - loss: 0.1343 - accuracy: 0.9637 - val_loss: 0.1317 - val_accuracy: 0.9622
# Epoch 11/20
# 60/60 [==============================] - 5s 85ms/step - loss: 0.1246 - accuracy: 0.9657 - val_loss: 0.1254 - val_accuracy: 0.9638
# Epoch 12/20
# 60/60 [==============================] - 5s 89ms/step - loss: 0.1165 - accuracy: 0.9685 - val_loss: 0.1173 - val_accuracy: 0.9668
# Epoch 13/20
# 60/60 [==============================] - 6s 93ms/step - loss: 0.1095 - accuracy: 0.9709 - val_loss: 0.1118 - val_accuracy: 0.9687
# Epoch 14/20
# 60/60 [==============================] - 6s 93ms/step - loss: 0.1037 - accuracy: 0.9720 - val_loss: 0.1066 - val_accuracy: 0.9691
# Epoch 15/20
# 60/60 [==============================] - 6s 95ms/step - loss: 0.0991 - accuracy: 0.9730 - val_loss: 0.1055 - val_accuracy: 0.9698
# Epoch 16/20
# 60/60 [==============================] - 6s 98ms/step - loss: 0.0945 - accuracy: 0.9744 - val_loss: 0.1009 - val_accuracy: 0.9714
# Epoch 17/20
# 60/60 [==============================] - 6s 95ms/step - loss: 0.0912 - accuracy: 0.9755 - val_loss: 0.0971 - val_accuracy: 0.9713
# Epoch 18/20
# 60/60 [==============================] - 5s 87ms/step - loss: 0.0869 - accuracy: 0.9766 - val_loss: 0.0984 - val_accuracy: 0.9721
# Epoch 19/20
# 60/60 [==============================] - 6s 93ms/step - loss: 0.0846 - accuracy: 0.9765 - val_loss: 0.0928 - val_accuracy: 0.9730
# Epoch 20/20
# 60/60 [==============================] - 6s 94ms/step - loss: 0.0810 - accuracy: 0.9778 - val_loss: 0.0903 - val_accuracy: 0.9741
# Test loss: 0.09027470648288727
# Test accuracy: 0.9740999937057495
# Computation time:106.027 sec

# %%
def show_prediction():
    n_show = 96
    y = model.predict(x_test)  # (A)
    plt.ﬁgure(2, ﬁgsize=(12, 8))
    plt.gray()
    for i in range(n_show):
        plt.subplot(8, 12, i + 1)
        x = x_test[i, :]
        x = x.reshape(28, 28)
        plt.pcolor(1 - x)
        wk = y[i, :]
        prediction = np.argmax(wk)
        plt.text(22, 25.5, "%d" % prediction, fontsize=12)
        if prediction != np.argmax(y_test[i, :]):
            plt.plot([0, 27], [1, 1], color='cornflowerblue', linewidth=5)
        plt.xlim(0, 27)
        plt.ylim(27, 0)
        plt.xticks([], "")
        plt.yticks([], "")


show_prediction()
plt.show()

# %%
plt.figure(1,figsize=(12,2.5))
plt.gray()
plt.subplots_adjust(wspace=0.2,hspace=0.2)
plt.subplot(2,9,10)
id_img = 12
x_img = x_test[id_img,:,:,0]
img_h = 28
img_w = 28
x_img = x_img.reshape(img_h,img_w)
plt.pcolor(-x_img)
plt.xlim(0,img_h)
plt.ylim(img_w,0)
plt.xticks([],"")
plt.yticks([],"")

w = model.layers[0].get_weights()[0]
max_w = np.max(w)
min_w = np.min(w)

for i in range(8):
    plt.subplot(2,9,i+2)
    w1 = w[:,:,0,i]
    w1 = w1.reshape(3,3)
    plt.pcolor(-w1,vmin=min_w,vmax=max_w)
    plt.xlim(0,3)
    plt.ylim(3,0)
    plt.xticks([],"")
    plt.yticks([],"")
    plt.title("%d" % i)
    plt.subplot(2,9,i+11)
    out_img = np.zeros_like(x_img)
    
    # filter
    for ih in range(img_h - 3 + 1):
        for iw in range(img_w - 3 + 1):
            img_part = x_img[ih:ih+3,iw:iw+3]
            out_img[ih+1,iw+1] = np.dot(img_part.reshape(-1),w1.reshape(-1))
        
    plt.pcolor(-out_img)
    plt.xlim(0,img_w)
    plt.ylim(img_h,0)
    plt.xticks([],"")
    plt.yticks([],"")

plt.show()

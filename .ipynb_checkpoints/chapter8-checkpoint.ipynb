# %%
from keras.datasets import mnist

(x_train,y_train),(x_test,y_test) = mnist.load_data()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(1,figsize=(18,6))
plt.subplots_adjust(wspace=0.5)
plt.gray()

for id in range(6):
    plt.subplot(2,6,id + 1)
    img = x_train[id,:,:]
    plt.pcolor(255-img)
    plt.text(22,26,"%d"% y_train[id],color='cornflowerblue',fontsize=18)
    plt.xlim(0,27)
    plt.ylim(27,0)

plt.show()

# %%
from keras.utils import np_utils

x_train = x_train.reshape(60000, 784)  # (A)
x_train = x_train.astype('float32')   # (B)
x_train = x_train / 255               # (C)
num_classes = 10
y_train = np_utils.to_categorical(y_train, num_classes)  # (D)

x_test = x_test.reshape(10000, 784)
x_test = x_test.astype('float32')
x_test = x_test / 255
y_test = np_utils.to_categorical(y_test, num_classes)


np.random.seed(1)                                         # (A)
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.optimizers import Adam

model = Sequential()                                      # (B)
model.add(Dense(16, input_dim=784, activation='sigmoid')) # (C)
model.add(Dense(10, activation='softmax'))                # (D)
model.compile(loss='categorical_crossentropy', 
              optimizer=Adam(), metrics=['accuracy'])     # (E)

import time

startTime = time.time()
history = model.fit(x_train, y_train, epochs=10, batch_size=1000,
                    verbose=1, validation_data=(x_test, y_test))  # (A)
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
print("Computation time:{0:.3f} sec".format(time.time() - startTime))
# Out:
# Epoch 1/10
# 60/60 [==============================] - 0s 6ms/step - loss: 2.0379 - accuracy: 0.3871 - val_loss: 1.7462 - val_accuracy: 0.6548
# Epoch 2/10
# 60/60 [==============================] - 0s 3ms/step - loss: 1.5602 - accuracy: 0.7216 - val_loss: 1.3811 - val_accuracy: 0.7839
# Epoch 3/10
# 60/60 [==============================] - 0s 3ms/step - loss: 1.2576 - accuracy: 0.8052 - val_loss: 1.1248 - val_accuracy: 0.8369
# Epoch 4/10
# 60/60 [==============================] - 0s 3ms/step - loss: 1.0413 - accuracy: 0.8403 - val_loss: 0.9407 - val_accuracy: 0.8613
# Epoch 5/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.8846 - accuracy: 0.8621 - val_loss: 0.8068 - val_accuracy: 0.8758
# Epoch 6/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.7690 - accuracy: 0.8734 - val_loss: 0.7079 - val_accuracy: 0.8836
# Epoch 7/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6823 - accuracy: 0.8803 - val_loss: 0.6325 - val_accuracy: 0.8875
# Epoch 8/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6158 - accuracy: 0.8862 - val_loss: 0.5746 - val_accuracy: 0.8923
# Epoch 9/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.5637 - accuracy: 0.8905 - val_loss: 0.5293 - val_accuracy: 0.8972
# Epoch 10/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.5220 - accuracy: 0.8944 - val_loss: 0.4924 - val_accuracy: 0.9000
# Test loss: 0.4923670291900635
# Test accuracy: 0.8999999761581421
# Computation time:3.138 sec

# %%
plt.figure(1,figsize=(10,4))
plt.subplots_adjust(wspace=0.5)

plt.subplot(1,2,1)
plt.plot(history.history['loss'],label='training',color='black')
plt.plot(history.history['val_loss'],label='test',color='cornflowerblue')
plt.ylim(0,10)
plt.legend()
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'],label='training',color='black')
plt.plot(history.history['val_accuracy'],label='test',color='cornflowerblue')
plt.ylim(0,1)
plt.legend()
plt.grid()
plt.xlabel('epoch')
plt.ylabel('acc')
plt.show()

# %%
def show_prediction():
    n_show = 96
    y = model.predict(x_test)
    plt.figure(2,figsize=(12,8))
    plt.gray()
    
    for i in range(n_show):
        plt.subplot(8,12,i+1)
        x = x_test[i,:]
        x = x.reshape(28,28)
        plt.pcolor(1-x)
        wk = y[i,:]
        prediction = np.argmax(wk)
        plt.text(22,25.5,"%d"% prediction,fontsize=12)
        
        if prediction != np.argmax(y_test[i,:]):
            plt.plot([0,27],[1,1],color='cornflowerblue',linewidth=5)
        
        plt.xlim(0,27)
        plt.ylim(27,0)
        plt.xticks([],"")
        plt.yticks([],"")

# main
show_prediction()
plt.show()

# %%
np.random.seed(1)
from keras.models import Sequential
from keras.layers import Dense,Activation
from keras.optimizers import Adam

model = Sequential()
model.add(Dense(16,input_dim=784,activation='relu'))
model.add(Dense(10,activation='softmax'))
model.compile(loss='categorical_crossentropy',optimizer=Adam(),metrics=['accuracy'])

startTime = time.time()
history = model.fit(x_train,y_train,batch_size=1000,epochs=10,verbose=1,validation_data=(x_test,y_test))
score = model.evaluate(x_test,y_test,verbose=0)
print('Test loss:',score[0])
print('Test accuracy:',score[1])
print('Computation time:{0:.3f}sec'.format(time.time() - startTime))
# Out:
# Epoch 1/10
# 60/60 [==============================] - 0s 7ms/step - loss: 1.4233 - accuracy: 0.6000 - val_loss: 0.7832 - val_accuracy: 0.8125
# Epoch 2/10
# 60/60 [==============================] - 0s 4ms/step - loss: 0.6202 - accuracy: 0.8432 - val_loss: 0.4871 - val_accuracy: 0.8771
# Epoch 3/10
# 60/60 [==============================] - 0s 4ms/step - loss: 0.4502 - accuracy: 0.8802 - val_loss: 0.3945 - val_accuracy: 0.8947
# Epoch 4/10
# 60/60 [==============================] - 0s 4ms/step - loss: 0.3827 - accuracy: 0.8951 - val_loss: 0.3505 - val_accuracy: 0.9030
# Epoch 5/10
# 60/60 [==============================] - 0s 4ms/step - loss: 0.3457 - accuracy: 0.9035 - val_loss: 0.3218 - val_accuracy: 0.9099
# Epoch 6/10
# 60/60 [==============================] - 0s 4ms/step - loss: 0.3216 - accuracy: 0.9101 - val_loss: 0.3050 - val_accuracy: 0.9146
# Epoch 7/10
# 60/60 [==============================] - 0s 4ms/step - loss: 0.3045 - accuracy: 0.9145 - val_loss: 0.2914 - val_accuracy: 0.9183
# Epoch 8/10
# 60/60 [==============================] - 0s 4ms/step - loss: 0.2912 - accuracy: 0.9174 - val_loss: 0.2798 - val_accuracy: 0.9219
# Epoch 9/10
# 60/60 [==============================] - 0s 4ms/step - loss: 0.2793 - accuracy: 0.9208 - val_loss: 0.2714 - val_accuracy: 0.9253
# Epoch 10/10
# 60/60 [==============================] - 0s 4ms/step - loss: 0.2704 - accuracy: 0.9237 - val_loss: 0.2651 - val_accuracy: 0.9250
# Test loss: 0.2651331424713135
# Test accuracy: 0.925000011920929
# Computation time:3.611sec

# %%
show_prediction()
plt.show()

# %%
# 1層目の重みの可視化
w = model.layers[0].get_weights()[0]
plt.figure(1,figsize=(12,3))
plt.gray()
plt.subplots_adjust(wspace=0.35,hspace=0.5)

for i in range(16):
    plt.subplot(2,8,i+1)
    w1 = w[:,i]
    w1 = w1.reshape(28,28)
    plt.pcolor(-w1)
    plt.xlim(0,27)
    plt.ylim(27,0)
    plt.xticks([],"")
    plt.yticks([],"")
    plt.title("%d" % i)

plt.show()

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import numpy as np
from keras.datasets import mnist
from keras.utils import np_utils

(x_train,y_train),(x_test,y_test) = mnist.load_data()
x_train = x_train.reshape(60000,28,28,1)
x_test = x_test.reshape(10000,28,28,1)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
num_classes = 10
y_train = np_utils.to_categorical(y_train,num_classes)
y_test = np_utils.to_categorical(y_test,num_classes)

# %%
from keras.datasets import mnist

(x_train,y_train),(x_test,y_test) = mnist.load_data()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(1,figsize=(18,6))
plt.subplots_adjust(wspace=0.5)
plt.gray()

for id in range(6):
    plt.subplot(2,6,id + 1)
    img = x_train[id,:,:]
    plt.pcolor(255-img)
    plt.text(22,26,"%d"% y_train[id],color='cornflowerblue',fontsize=18)
    plt.xlim(0,27)
    plt.ylim(27,0)

plt.show()

# %%
from keras.utils import np_utils

x_train = x_train.reshape(60000, 784)  # (A)
x_train = x_train.astype('float32')   # (B)
x_train = x_train / 255               # (C)
num_classes = 10
y_train = np_utils.to_categorical(y_train, num_classes)  # (D)

x_test = x_test.reshape(10000, 784)
x_test = x_test.astype('float32')
x_test = x_test / 255
y_test = np_utils.to_categorical(y_test, num_classes)


np.random.seed(1)                                         # (A)
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.optimizers import Adam

model = Sequential()                                      # (B)
model.add(Dense(16, input_dim=784, activation='sigmoid')) # (C)
model.add(Dense(10, activation='softmax'))                # (D)
model.compile(loss='categorical_crossentropy', 
              optimizer=Adam(), metrics=['accuracy'])     # (E)

import time

startTime = time.time()
history = model.fit(x_train, y_train, epochs=10, batch_size=1000,
                    verbose=1, validation_data=(x_test, y_test))  # (A)
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
print("Computation time:{0:.3f} sec".format(time.time() - startTime))
# Out:
# Epoch 1/10
# 60/60 [==============================] - 0s 6ms/step - loss: 2.0071 - accuracy: 0.4183 - val_loss: 1.7151 - val_accuracy: 0.7010
# Epoch 2/10
# 60/60 [==============================] - 0s 3ms/step - loss: 1.5493 - accuracy: 0.7567 - val_loss: 1.3772 - val_accuracy: 0.7966
# Epoch 3/10
# 60/60 [==============================] - 0s 3ms/step - loss: 1.2703 - accuracy: 0.8110 - val_loss: 1.1430 - val_accuracy: 0.8361
# Epoch 4/10
# 60/60 [==============================] - 0s 3ms/step - loss: 1.0646 - accuracy: 0.8395 - val_loss: 0.9657 - val_accuracy: 0.8573
# Epoch 5/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.9077 - accuracy: 0.8573 - val_loss: 0.8306 - val_accuracy: 0.8681
# Epoch 6/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.7879 - accuracy: 0.8671 - val_loss: 0.7280 - val_accuracy: 0.8766
# Epoch 7/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6967 - accuracy: 0.8762 - val_loss: 0.6501 - val_accuracy: 0.8833
# Epoch 8/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6268 - accuracy: 0.8826 - val_loss: 0.5891 - val_accuracy: 0.8880
# Epoch 9/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.5723 - accuracy: 0.8877 - val_loss: 0.5422 - val_accuracy: 0.8917
# Epoch 10/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.5289 - accuracy: 0.8917 - val_loss: 0.5042 - val_accuracy: 0.8954
# Test loss: 0.5042486190795898
# Test accuracy: 0.8953999876976013
# Computation time:3.044 sec

# %%
plt.figure(1,figsize=(10,4))
plt.subplots_adjust(wspace=0.5)

plt.subplot(1,2,1)
plt.plot(history.history['loss'],label='training',color='black')
plt.plot(history.history['val_loss'],label='test',color='cornflowerblue')
plt.ylim(0,10)
plt.legend()
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'],label='training',color='black')
plt.plot(history.history['val_accuracy'],label='test',color='cornflowerblue')
plt.ylim(0,1)
plt.legend()
plt.grid()
plt.xlabel('epoch')
plt.ylabel('acc')
plt.show()

# %%
def show_prediction():
    n_show = 96
    y = model.predict(x_test)
    plt.figure(2,figsize=(12,8))
    plt.gray()
    
    for i in range(n_show):
        plt.subplot(8,12,i+1)
        x = x_test[i,:]
        x = x.reshape(28,28)
        plt.pcolor(1-x)
        wk = y[i,:]
        prediction = np.argmax(wk)
        plt.text(22,25.5,"%d"% prediction,fontsize=12)
        
        if prediction != np.argmax(y_test[i,:]):
            plt.plot([0,27],[1,1],color='cornflowerblue',linewidth=5)
        
        plt.xlim(0,27)
        plt.ylim(27,0)
        plt.xticks([],"")
        plt.yticks([],"")

# main
show_prediction()
plt.show()

# %%
np.random.seed(1)
from keras.models import Sequential
from keras.layers import Dense,Activation
from keras.optimizers import Adam

model = Sequential()
model.add(Dense(16,input_dim=784,activation='relu'))
model.add(Dense(10,activation='softmax'))
model.compile(loss='categorical_crossentropy',optimizer=Adam(),metrics=['accuracy'])

startTime = time.time()
history = model.fit(x_train,y_train,batch_size=1000,epochs=10,verbose=1,validation_data=(x_test,y_test))
score = model.evaluate(x_test,y_test,verbose=0)
print('Test loss:',score[0])
print('Test accuracy:',score[1])
print('Computation time:{0:.3f}sec'.format(time.time() - startTime))
# Out:
# Epoch 1/10
# 60/60 [==============================] - 0s 5ms/step - loss: 1.5845 - accuracy: 0.5386 - val_loss: 0.9640 - val_accuracy: 0.7736
# Epoch 2/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.7339 - accuracy: 0.8248 - val_loss: 0.5399 - val_accuracy: 0.8713
# Epoch 3/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.4825 - accuracy: 0.8781 - val_loss: 0.4098 - val_accuracy: 0.8965
# Epoch 4/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3913 - accuracy: 0.8971 - val_loss: 0.3524 - val_accuracy: 0.9084
# Epoch 5/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3456 - accuracy: 0.9067 - val_loss: 0.3216 - val_accuracy: 0.9154
# Epoch 6/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3180 - accuracy: 0.9130 - val_loss: 0.3004 - val_accuracy: 0.9198
# Epoch 7/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2988 - accuracy: 0.9174 - val_loss: 0.2856 - val_accuracy: 0.9217
# Epoch 8/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2848 - accuracy: 0.9207 - val_loss: 0.2743 - val_accuracy: 0.9246
# Epoch 9/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2734 - accuracy: 0.9236 - val_loss: 0.2664 - val_accuracy: 0.9278
# Epoch 10/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2639 - accuracy: 0.9265 - val_loss: 0.2582 - val_accuracy: 0.9297
# Test loss: 0.2582201063632965
# Test accuracy: 0.9297000169754028
# Computation time:2.827sec

# %%
show_prediction()
plt.show()

# %%
# 1層目の重みの可視化
w = model.layers[0].get_weights()[0]
plt.figure(1,figsize=(12,3))
plt.gray()
plt.subplots_adjust(wspace=0.35,hspace=0.5)

for i in range(16):
    plt.subplot(2,8,i+1)
    w1 = w[:,i]
    w1 = w1.reshape(28,28)
    plt.pcolor(-w1)
    plt.xlim(0,27)
    plt.ylim(27,0)
    plt.xticks([],"")
    plt.yticks([],"")
    plt.title("%d" % i)

plt.show()

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import numpy as np
from keras.datasets import mnist
from keras.utils import np_utils

(x_train,y_train),(x_test,y_test) = mnist.load_data()
x_train = x_train.reshape(60000,28,28,1)
x_test = x_test.reshape(10000,28,28,1)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
num_classes = 10
y_train = np_utils.to_categorical(y_train,num_classes)
y_test = np_utils.to_categorical(y_test,num_classes)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

id_img = 2
myfil1 = np.array([[1,1,1],[1,1,1],[-2,-2,-2]],dtype=float)
myfil2 = np.array([[-2,1,1],[-2,1,1],[-2,1,1]],dtype=float)

x_img = x_train[id_img,:,:,0]
img_h = 28
img_w = 28
x_img = x_img.reshape(img_h,img_w)
out_img1 = np.zeros_like(x_img)
out_img2 = np.zeros_like(x_img)

# filter
for ih in range(img_h - 3 + 1):
    for iw in range(img_w - 3 + 1 ):
        img_part = x_img[ih:ih + 3,iw:iw + 3]
        out_img1[ih+1,iw+1] = np.dot(img_part.reshape(-1),myfil1.reshape(-1))
        out_img2[ih+1,iw+1] = np.dot(img_part.reshape(-1),myfil2.reshape(-1))

# show
plt.figure(1,figsize=(12,3.2))
plt.subplots_adjust(wspace=0.5)
plt.gray()
plt.subplot(1,3,1)
plt.pcolor(1 - x_img)
plt.xlim(-1,29)
plt.ylim(29,-1)
plt.subplot(1,3,2)
plt.pcolor(-out_img1)
plt.xlim(-1,29)
plt.ylim(29,-1)
plt.subplot(1,3,3)
plt.pcolor(-out_img2)
plt.xlim(-1,29)
plt.ylim(29,-1)
plt.show()

# %%
np.random.seed(1)
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D
from keras.layers import Activation,Dropout,Flatten,Dense
from keras.optimizers import Adam
import time

model = Sequential()
model.add(Conv2D(8, (3, 3), padding='same',
           input_shape=(28, 28, 1), activation='relu'))
model.add(Flatten())
model.add(Dense(10,activation='softmax'))
model.compile(loss='categorical_crossentropy',optimizer=Adam(),metrics=['accuracy'])
startTime = time.time()
history = model.fit(x_train,y_train,batch_size=1000,epochs=20,verbose=1,validation_data=(x_test,y_test))
score = model.evaluate(x_test,y_test,verbose=0)
print('Test loss:',score[0])
print('Test accuracy:',score[1])
print('Computation time:{0:.3f} sec'.format(time.time() - startTime))
# Out:
# Epoch 1/20
# 60/60 [==============================] - 4s 59ms/step - loss: 1.0308 - accuracy: 0.7761 - val_loss: 0.3946 - val_accuracy: 0.8901
# Epoch 2/20
# 60/60 [==============================] - 3s 58ms/step - loss: 0.3368 - accuracy: 0.9024 - val_loss: 0.2764 - val_accuracy: 0.9223
# Epoch 3/20
# 60/60 [==============================] - 4s 58ms/step - loss: 0.2503 - accuracy: 0.9287 - val_loss: 0.2144 - val_accuracy: 0.9405
# Epoch 4/20
# 60/60 [==============================] - 4s 61ms/step - loss: 0.1943 - accuracy: 0.9453 - val_loss: 0.1679 - val_accuracy: 0.9519
# Epoch 5/20
# 60/60 [==============================] - 4s 70ms/step - loss: 0.1557 - accuracy: 0.9569 - val_loss: 0.1389 - val_accuracy: 0.9608
# Epoch 6/20
# 60/60 [==============================] - 5s 81ms/step - loss: 0.1297 - accuracy: 0.9647 - val_loss: 0.1221 - val_accuracy: 0.9666
# Epoch 7/20
# 60/60 [==============================] - 5s 81ms/step - loss: 0.1106 - accuracy: 0.9703 - val_loss: 0.1057 - val_accuracy: 0.9718
# Epoch 8/20
# 60/60 [==============================] - 5s 80ms/step - loss: 0.0969 - accuracy: 0.9745 - val_loss: 0.0941 - val_accuracy: 0.9735
# Epoch 9/20
# 60/60 [==============================] - 5s 79ms/step - loss: 0.0872 - accuracy: 0.9768 - val_loss: 0.0878 - val_accuracy: 0.9753
# Epoch 10/20
# 60/60 [==============================] - 5s 79ms/step - loss: 0.0791 - accuracy: 0.9786 - val_loss: 0.0802 - val_accuracy: 0.9766
# Epoch 11/20
# 60/60 [==============================] - 5s 82ms/step - loss: 0.0732 - accuracy: 0.9801 - val_loss: 0.0750 - val_accuracy: 0.9768
# Epoch 12/20
# 60/60 [==============================] - 5s 80ms/step - loss: 0.0669 - accuracy: 0.9819 - val_loss: 0.0718 - val_accuracy: 0.9779
# Epoch 13/20
# 60/60 [==============================] - 5s 87ms/step - loss: 0.0641 - accuracy: 0.9822 - val_loss: 0.0699 - val_accuracy: 0.9788
# Epoch 14/20
# 60/60 [==============================] - 5s 83ms/step - loss: 0.0595 - accuracy: 0.9835 - val_loss: 0.0704 - val_accuracy: 0.9789
# Epoch 15/20
# 60/60 [==============================] - 5s 86ms/step - loss: 0.0564 - accuracy: 0.9847 - val_loss: 0.0665 - val_accuracy: 0.9811
# Epoch 16/20
# 60/60 [==============================] - 5s 86ms/step - loss: 0.0539 - accuracy: 0.9855 - val_loss: 0.0696 - val_accuracy: 0.9796
# Epoch 17/20
# 60/60 [==============================] - 5s 83ms/step - loss: 0.0510 - accuracy: 0.9859 - val_loss: 0.0618 - val_accuracy: 0.9819
# Epoch 18/20
# 60/60 [==============================] - 5s 83ms/step - loss: 0.0482 - accuracy: 0.9871 - val_loss: 0.0632 - val_accuracy: 0.9807
# Epoch 19/20
# 60/60 [==============================] - 5s 85ms/step - loss: 0.0471 - accuracy: 0.9866 - val_loss: 0.0614 - val_accuracy: 0.9819
# Epoch 20/20
# 60/60 [==============================] - 5s 87ms/step - loss: 0.0447 - accuracy: 0.9877 - val_loss: 0.0602 - val_accuracy: 0.9814
# Test loss: 0.060162343084812164
# Test accuracy: 0.9814000129699707
# Computation time:95.676 sec

# %%
def show_prediction():
    n_show = 96
    y = model.predict(x_test)  # (A)
    plt.ﬁgure(2, ﬁgsize=(12, 8))
    plt.gray()
    for i in range(n_show):
        plt.subplot(8, 12, i + 1)
        x = x_test[i, :]
        x = x.reshape(28, 28)
        plt.pcolor(1 - x)
        wk = y[i, :]
        prediction = np.argmax(wk)
        plt.text(22, 25.5, "%d" % prediction, fontsize=12)
        if prediction != np.argmax(y_test[i, :]):
            plt.plot([0, 27], [1, 1], color='cornflowerblue', linewidth=5)
        plt.xlim(0, 27)
        plt.ylim(27, 0)
        plt.xticks([], "")
        plt.yticks([], "")


show_prediction()
plt.show()

# %%
from keras.datasets import mnist

(x_train,y_train),(x_test,y_test) = mnist.load_data()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(1,figsize=(18,6))
plt.subplots_adjust(wspace=0.5)
plt.gray()

for id in range(6):
    plt.subplot(2,6,id + 1)
    img = x_train[id,:,:]
    plt.pcolor(255-img)
    plt.text(22,26,"%d"% y_train[id],color='cornflowerblue',fontsize=18)
    plt.xlim(0,27)
    plt.ylim(27,0)

plt.show()

# %%
from keras.utils import np_utils

x_train = x_train.reshape(60000, 784)  # (A)
x_train = x_train.astype('float32')   # (B)
x_train = x_train / 255               # (C)
num_classes = 10
y_train = np_utils.to_categorical(y_train, num_classes)  # (D)

x_test = x_test.reshape(10000, 784)
x_test = x_test.astype('float32')
x_test = x_test / 255
y_test = np_utils.to_categorical(y_test, num_classes)


np.random.seed(1)                                         # (A)
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.optimizers import Adam

model = Sequential()                                      # (B)
model.add(Dense(16, input_dim=784, activation='sigmoid')) # (C)
model.add(Dense(10, activation='softmax'))                # (D)
model.compile(loss='categorical_crossentropy', 
              optimizer=Adam(), metrics=['accuracy'])     # (E)

import time

startTime = time.time()
history = model.fit(x_train, y_train, epochs=10, batch_size=1000,
                    verbose=1, validation_data=(x_test, y_test))  # (A)
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
print("Computation time:{0:.3f} sec".format(time.time() - startTime))
# Out:
# Epoch 1/10
# 60/60 [==============================] - 0s 6ms/step - loss: 2.0130 - accuracy: 0.4292 - val_loss: 1.7039 - val_accuracy: 0.6791
# Epoch 2/10
# 60/60 [==============================] - 0s 4ms/step - loss: 1.5317 - accuracy: 0.7395 - val_loss: 1.3633 - val_accuracy: 0.8003
# Epoch 3/10
# 60/60 [==============================] - 0s 3ms/step - loss: 1.2517 - accuracy: 0.8079 - val_loss: 1.1281 - val_accuracy: 0.8342
# Epoch 4/10
# 60/60 [==============================] - 0s 4ms/step - loss: 1.0493 - accuracy: 0.8349 - val_loss: 0.9546 - val_accuracy: 0.8533
# Epoch 5/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.8985 - accuracy: 0.8503 - val_loss: 0.8250 - val_accuracy: 0.8633
# Epoch 6/10
# 60/60 [==============================] - 0s 4ms/step - loss: 0.7849 - accuracy: 0.8619 - val_loss: 0.7261 - val_accuracy: 0.8716
# Epoch 7/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6977 - accuracy: 0.8701 - val_loss: 0.6501 - val_accuracy: 0.8783
# Epoch 8/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6298 - accuracy: 0.8777 - val_loss: 0.5908 - val_accuracy: 0.8848
# Epoch 9/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.5758 - accuracy: 0.8831 - val_loss: 0.5424 - val_accuracy: 0.8889
# Epoch 10/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.5324 - accuracy: 0.8890 - val_loss: 0.5037 - val_accuracy: 0.8930
# Test loss: 0.5037451386451721
# Test accuracy: 0.8930000066757202
# Computation time:3.202 sec

# %%
plt.figure(1,figsize=(10,4))
plt.subplots_adjust(wspace=0.5)

plt.subplot(1,2,1)
plt.plot(history.history['loss'],label='training',color='black')
plt.plot(history.history['val_loss'],label='test',color='cornflowerblue')
plt.ylim(0,10)
plt.legend()
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'],label='training',color='black')
plt.plot(history.history['val_accuracy'],label='test',color='cornflowerblue')
plt.ylim(0,1)
plt.legend()
plt.grid()
plt.xlabel('epoch')
plt.ylabel('acc')
plt.show()

# %%
def show_prediction():
    n_show = 96
    y = model.predict(x_test)
    plt.figure(2,figsize=(12,8))
    plt.gray()
    
    for i in range(n_show):
        plt.subplot(8,12,i+1)
        x = x_test[i,:]
        x = x.reshape(28,28)
        plt.pcolor(1-x)
        wk = y[i,:]
        prediction = np.argmax(wk)
        plt.text(22,25.5,"%d"% prediction,fontsize=12)
        
        if prediction != np.argmax(y_test[i,:]):
            plt.plot([0,27],[1,1],color='cornflowerblue',linewidth=5)
        
        plt.xlim(0,27)
        plt.ylim(27,0)
        plt.xticks([],"")
        plt.yticks([],"")

# main
show_prediction()
plt.show()

# %%
np.random.seed(1)
from keras.models import Sequential
from keras.layers import Dense,Activation
from keras.optimizers import Adam

model = Sequential()
model.add(Dense(16,input_dim=784,activation='relu'))
model.add(Dense(10,activation='softmax'))
model.compile(loss='categorical_crossentropy',optimizer=Adam(),metrics=['accuracy'])

startTime = time.time()
history = model.fit(x_train,y_train,batch_size=1000,epochs=10,verbose=1,validation_data=(x_test,y_test))
score = model.evaluate(x_test,y_test,verbose=0)
print('Test loss:',score[0])
print('Test accuracy:',score[1])
print('Computation time:{0:.3f}sec'.format(time.time() - startTime))
# Out:
# Epoch 1/10
# 60/60 [==============================] - 0s 5ms/step - loss: 1.4691 - accuracy: 0.6006 - val_loss: 0.8306 - val_accuracy: 0.8299
# Epoch 2/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6376 - accuracy: 0.8531 - val_loss: 0.4780 - val_accuracy: 0.8847
# Epoch 3/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.4451 - accuracy: 0.8842 - val_loss: 0.3845 - val_accuracy: 0.8987
# Epoch 4/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3754 - accuracy: 0.8991 - val_loss: 0.3380 - val_accuracy: 0.9085
# Epoch 5/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3381 - accuracy: 0.9077 - val_loss: 0.3116 - val_accuracy: 0.9142
# Epoch 6/10
# 60/60 [==============================] - 0s 4ms/step - loss: 0.3147 - accuracy: 0.9134 - val_loss: 0.2959 - val_accuracy: 0.9172
# Epoch 7/10
# 60/60 [==============================] - 0s 4ms/step - loss: 0.2977 - accuracy: 0.9172 - val_loss: 0.2829 - val_accuracy: 0.9203
# Epoch 8/10
# 60/60 [==============================] - 0s 4ms/step - loss: 0.2845 - accuracy: 0.9207 - val_loss: 0.2730 - val_accuracy: 0.9225
# Epoch 9/10
# 60/60 [==============================] - 0s 4ms/step - loss: 0.2740 - accuracy: 0.9238 - val_loss: 0.2667 - val_accuracy: 0.9247
# Epoch 10/10
# 60/60 [==============================] - 0s 4ms/step - loss: 0.2643 - accuracy: 0.9265 - val_loss: 0.2585 - val_accuracy: 0.9278
# Test loss: 0.25848111510276794
# Test accuracy: 0.9277999997138977
# Computation time:3.184sec

# %%
show_prediction()
plt.show()

# %%
# 1層目の重みの可視化
w = model.layers[0].get_weights()[0]
plt.figure(1,figsize=(12,3))
plt.gray()
plt.subplots_adjust(wspace=0.35,hspace=0.5)

for i in range(16):
    plt.subplot(2,8,i+1)
    w1 = w[:,i]
    w1 = w1.reshape(28,28)
    plt.pcolor(-w1)
    plt.xlim(0,27)
    plt.ylim(27,0)
    plt.xticks([],"")
    plt.yticks([],"")
    plt.title("%d" % i)

plt.show()

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import numpy as np
from keras.datasets import mnist
from keras.utils import np_utils

(x_train,y_train),(x_test,y_test) = mnist.load_data()
x_train = x_train.reshape(60000,28,28,1)
x_test = x_test.reshape(10000,28,28,1)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
num_classes = 10
y_train = np_utils.to_categorical(y_train,num_classes)
y_test = np_utils.to_categorical(y_test,num_classes)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

id_img = 2
myfil1 = np.array([[1,1,1],[1,1,1],[-2,-2,-2]],dtype=float)
myfil2 = np.array([[-2,1,1],[-2,1,1],[-2,1,1]],dtype=float)

x_img = x_train[id_img,:,:,0]
img_h = 28
img_w = 28
x_img = x_img.reshape(img_h,img_w)
out_img1 = np.zeros_like(x_img)
out_img2 = np.zeros_like(x_img)

# filter
for ih in range(img_h - 3 + 1):
    for iw in range(img_w - 3 + 1 ):
        img_part = x_img[ih:ih + 3,iw:iw + 3]
        out_img1[ih+1,iw+1] = np.dot(img_part.reshape(-1),myfil1.reshape(-1))
        out_img2[ih+1,iw+1] = np.dot(img_part.reshape(-1),myfil2.reshape(-1))

# show
plt.figure(1,figsize=(12,3.2))
plt.subplots_adjust(wspace=0.5)
plt.gray()
plt.subplot(1,3,1)
plt.pcolor(1 - x_img)
plt.xlim(-1,29)
plt.ylim(29,-1)
plt.subplot(1,3,2)
plt.pcolor(-out_img1)
plt.xlim(-1,29)
plt.ylim(29,-1)
plt.subplot(1,3,3)
plt.pcolor(-out_img2)
plt.xlim(-1,29)
plt.ylim(29,-1)
plt.show()

# %%
np.random.seed(1)
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D
from keras.layers import Activation,Dropout,Flatten,Dense
from keras.optimizers import Adam
import time

model = Sequential()
model.add(Conv2D(8, (3, 3), padding='same',
           input_shape=(28, 28, 1), activation='relu'))
model.add(Flatten())
model.add(Dense(10,activation='softmax'))
model.compile(loss='categorical_crossentropy',optimizer=Adam(),metrics=['accuracy'])
startTime = time.time()
history = model.fit(x_train,y_train,batch_size=1000,epochs=20,verbose=1,validation_data=(x_test,y_test))
score = model.evaluate(x_test,y_test,verbose=0)
print('Test loss:',score[0])
print('Test accuracy:',score[1])
print('Computation time:{0:.3f} sec'.format(time.time() - startTime))
# Out:
# Epoch 1/20
# 60/60 [==============================] - 5s 91ms/step - loss: 0.9955 - accuracy: 0.7872 - val_loss: 0.3780 - val_accuracy: 0.9010
# Epoch 2/20
# 60/60 [==============================] - 6s 98ms/step - loss: 0.3221 - accuracy: 0.9093 - val_loss: 0.2609 - val_accuracy: 0.9285
# Epoch 3/20
# 60/60 [==============================] - 6s 97ms/step - loss: 0.2423 - accuracy: 0.9321 - val_loss: 0.2103 - val_accuracy: 0.9425
# Epoch 4/20
# 60/60 [==============================] - 6s 95ms/step - loss: 0.1959 - accuracy: 0.9456 - val_loss: 0.1724 - val_accuracy: 0.9526
# Epoch 5/20
# 60/60 [==============================] - 5s 90ms/step - loss: 0.1621 - accuracy: 0.9550 - val_loss: 0.1484 - val_accuracy: 0.9585
# Epoch 6/20
# 60/60 [==============================] - 5s 91ms/step - loss: 0.1375 - accuracy: 0.9625 - val_loss: 0.1268 - val_accuracy: 0.9651
# Epoch 7/20
# 60/60 [==============================] - 6s 97ms/step - loss: 0.1193 - accuracy: 0.9675 - val_loss: 0.1161 - val_accuracy: 0.9680
# Epoch 8/20
# 60/60 [==============================] - 5s 91ms/step - loss: 0.1050 - accuracy: 0.9718 - val_loss: 0.1034 - val_accuracy: 0.9711
# Epoch 9/20
# 60/60 [==============================] - 5s 91ms/step - loss: 0.0945 - accuracy: 0.9752 - val_loss: 0.0959 - val_accuracy: 0.9734
# Epoch 10/20
# 60/60 [==============================] - 6s 96ms/step - loss: 0.0865 - accuracy: 0.9771 - val_loss: 0.0890 - val_accuracy: 0.9739
# Epoch 11/20
# 60/60 [==============================] - 6s 97ms/step - loss: 0.0799 - accuracy: 0.9784 - val_loss: 0.0838 - val_accuracy: 0.9755
# Epoch 12/20
# 60/60 [==============================] - 6s 94ms/step - loss: 0.0747 - accuracy: 0.9798 - val_loss: 0.0806 - val_accuracy: 0.9761
# Epoch 13/20
# 60/60 [==============================] - 6s 96ms/step - loss: 0.0695 - accuracy: 0.9809 - val_loss: 0.0779 - val_accuracy: 0.9762
# Epoch 14/20
# 60/60 [==============================] - 6s 95ms/step - loss: 0.0654 - accuracy: 0.9822 - val_loss: 0.0736 - val_accuracy: 0.9779
# Epoch 15/20
# 60/60 [==============================] - 6s 100ms/step - loss: 0.0623 - accuracy: 0.9827 - val_loss: 0.0740 - val_accuracy: 0.9773
# Epoch 16/20
# 60/60 [==============================] - 6s 97ms/step - loss: 0.0594 - accuracy: 0.9838 - val_loss: 0.0706 - val_accuracy: 0.9778
# Epoch 17/20
# 60/60 [==============================] - 6s 96ms/step - loss: 0.0563 - accuracy: 0.9845 - val_loss: 0.0706 - val_accuracy: 0.9770
# Epoch 18/20
# 60/60 [==============================] - 6s 98ms/step - loss: 0.0538 - accuracy: 0.9852 - val_loss: 0.0705 - val_accuracy: 0.9780
# Epoch 19/20
# 60/60 [==============================] - 6s 95ms/step - loss: 0.0517 - accuracy: 0.9859 - val_loss: 0.0701 - val_accuracy: 0.9780
# Epoch 20/20
# 60/60 [==============================] - 6s 96ms/step - loss: 0.0501 - accuracy: 0.9860 - val_loss: 0.0692 - val_accuracy: 0.9780
# Test loss: 0.06917530298233032
# Test accuracy: 0.9779999852180481
# Computation time:117.043 sec

# %%
def show_prediction():
    n_show = 96
    y = model.predict(x_test)  # (A)
    plt.ﬁgure(2, ﬁgsize=(12, 8))
    plt.gray()
    for i in range(n_show):
        plt.subplot(8, 12, i + 1)
        x = x_test[i, :]
        x = x.reshape(28, 28)
        plt.pcolor(1 - x)
        wk = y[i, :]
        prediction = np.argmax(wk)
        plt.text(22, 25.5, "%d" % prediction, fontsize=12)
        if prediction != np.argmax(y_test[i, :]):
            plt.plot([0, 27], [1, 1], color='cornflowerblue', linewidth=5)
        plt.xlim(0, 27)
        plt.ylim(27, 0)
        plt.xticks([], "")
        plt.yticks([], "")


show_prediction()
plt.show()

# %%
plt.figure(1,figsize=(12,2.5))
plt.gray()
plt.subplots_adjust(wspace=0.2,hspace=0.2)
plt.subplot(2,9,10)
id_img = 12
x_img = x_test[id_img,:,:,0]
img_h = 28
img_w = 28
x_img = x_img.reshape(img_h,img_w)
plt.pcolor(-x_img)
plt.xlim(0,img_h)
plt.ylim(img_w,0)
plt.xticks([],"")
plt.yticks([],"")

w = model.layers[0].get_weights()[0]
max_w = np.max(w)
min_w = np.min(w)

for i in range(8):
    plt.subplot(2,9,i+2)
    w1 = w[:,:,0,i]
    w1 = w1.reshape(3,3)
    plt.pcolor(-w1,vmin=min_w,vmax=max_w)
    plt.xlim(0,3)
    plt.ylim(3,0)
    plt.xticks([],"")
    plt.yticks([],"")
    plt.title("%d" % i)
    plt.subplot(2,9,i+11)
    out_img = np.zeros_like(x_img)
    
    # filter
    for ih in range(img_h - 3 + 1):
        for iw in range(img_w - 3 + 1):
            img_part = x_img[ih:ih+3,iw:iw+3]
            out_img[ih+1,iw+1] = np.dot(img_part.reshape(-1),w1.reshape(-1))
        
    plt.pcolor(-out_img)
    plt.xlim(0,img_w)
    plt.ylim(img_h,0)
    plt.xticks([],"")
    plt.yticks([],"")

plt.show()

# %%
import numpy as np
np.random.seed(1)
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import Adam
import time

model = Sequential()
model.add(Conv2D(16,(3,3),input_shape=(28,28,1),activation='relu'))
model.add(Conv2D(32,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size(2,2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(num_classes,activation='softmax'))

model.compile(loss='categorical_crossentropy',optimizer=Adam(),metrics=['accuracy'])

startTime = time.time()

history = model.fit(x_train,y_train,batch_size=1000,epochs=20,verbose=1,validation_data=(x_test,y_test))

score = model.evaluate(x_test,y_test,verbose=0)
print('Test loss:',score[0])
print('Test accuracy:',score[1])
print('Computing time:{0:.3f} sec'.format(time.time() - startTime))
